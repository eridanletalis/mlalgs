# %%
from sklearn.tree import DecisionTreeRegressor

from sklearn import model_selection
import numpy as np

# %%
from sklearn.datasets import load_diabetes

# %%
X, y = load_diabetes(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.25)

# %%
import matplotlib.pyplot as plt

# %%
def gb_predict(X, trees_list, coef_list, eta):
    # Реализуемый алгоритм градиентного бустинга будет инициализироваться нулевыми значениями,
    # поэтому все деревья из списка trees_list уже являются дополнительными и при предсказании прибавляются с шагом eta
    return np.array([sum([eta* coef * alg.predict([x])[0] for alg, coef in zip(trees_list, coef_list)]) for x in X])

# %%
def mean_squared_error(y_real, prediction):
    return (sum((y_real - prediction)**2)) / len(y_real)

# %%
def bias(y, z):
    return (y - z)

# %%
def gb_fit(n_trees, max_depth, X_train, X_test, y_train, y_test, coefs, eta):
    
    # Деревья будем записывать в список
    trees = []
    
    # Будем записывать ошибки на обучающей и тестовой выборке на каждой итерации в список
    train_errors = []
    test_errors = []
    
    for i in range(n_trees):
        tree = DecisionTreeRegressor(max_depth=max_depth, random_state=42)

        # инициализируем бустинг начальным алгоритмом, возвращающим ноль, 
        # поэтому первый алгоритм просто обучаем на выборке и добавляем в список
        if len(trees) == 0:
            # обучаем первое дерево на обучающей выборке
            tree.fit(X_train, y_train)
            
            train_errors.append(mean_squared_error(y_train, gb_predict(X_train, trees, coefs, eta)))
            test_errors.append(mean_squared_error(y_test, gb_predict(X_test, trees, coefs, eta)))
        else:
            # Получим ответы на текущей композиции
            target = gb_predict(X_train, trees, coefs, eta)
            
            # алгоритмы начиная со второго обучаем на сдвиг
            tree.fit(X_train, bias(y_train, target))
            
            train_errors.append(mean_squared_error(y_train, gb_predict(X_train, trees, coefs, eta)))
            test_errors.append(mean_squared_error(y_test, gb_predict(X_test, trees, coefs, eta)))

        trees.append(tree)
        
    return trees, train_errors, test_errors

# %%
# Число деревьев в ансамбле
n_trees = 10

# для простоты примем коэффициенты равными 1
coefs = [1] * n_trees

# Максимальная глубина деревьев
max_depth = 3

# Шаг
eta = 1

trees, train_errors, test_errors = gb_fit(n_trees, max_depth, X_train, X_test, y_train, y_test, coefs, eta)

# %%
def evaluate_alg(X_train, X_test, y_train, y_test, trees, coefs, eta):
    train_prediction = gb_predict(X_train, trees, coefs, eta)

    print(f'Ошибка алгоритма из {n_trees} деревьев глубиной {max_depth} \
    с шагом {eta} на тренировочной выборке: {mean_squared_error(y_train, train_prediction)}')

    test_prediction = gb_predict(X_test, trees, coefs, eta)

    print(f'Ошибка алгоритма из {n_trees} деревьев глубиной {max_depth} \
    с шагом {eta} на тестовой выборке: {mean_squared_error(y_test, test_prediction)}')

# %%
evaluate_alg(X_train, X_test, y_train, y_test, trees, coefs, eta)
# Out:
# Ошибка алгоритма из 10 деревьев глубиной 3     с шагом 1 на тренировочной выборке: 1034.8614605947487
# Ошибка алгоритма из 10 деревьев глубиной 3     с шагом 1 на тестовой выборке: 5308.904103887541

# %%
def get_error_plot(n_trees, train_err, test_err):
    plt.xlabel('Iteration number')
    plt.ylabel('MSE')
    plt.xlim(0, n_trees)
    plt.plot(list(range(n_trees)), train_err, label='train error')
    plt.plot(list(range(n_trees)), test_err, label='test error')
    plt.legend(loc='upper right')
    plt.show()

# %%
get_error_plot(n_trees, train_errors, test_errors)

# %%
n_trees = 100
coefs = [1] * n_trees

trees, train_errors, test_errors = gb_fit(n_trees, max_depth, X_train, X_test, y_train, y_test, coefs, eta)

# %%
evaluate_alg(X_train, X_test, y_train, y_test, trees, coefs, eta)
# Out:
# Ошибка алгоритма из 100 деревьев глубиной 3     с шагом 1 на тренировочной выборке: 0.7965084882624252
# Ошибка алгоритма из 100 деревьев глубиной 3     с шагом 1 на тестовой выборке: 7009.160477146602

# %%
get_error_plot(n_trees, train_errors, test_errors)

# %%
eta = 0.1

trees, train_errors, test_errors = gb_fit(n_trees, max_depth, X_train, X_test, y_train, y_test, coefs, eta)

# %%
evaluate_alg(X_train, X_test, y_train, y_test, trees, coefs, eta)
# Out:
# Ошибка алгоритма из 100 деревьев глубиной 3     с шагом 0.1 на тренировочной выборке: 888.6746347185468
# Ошибка алгоритма из 100 деревьев глубиной 3     с шагом 0.1 на тестовой выборке: 3465.350570101073

# %%
get_error_plot(n_trees, train_errors, test_errors)

# %%
eta = 0.01

trees, train_errors, test_errors = gb_fit(n_trees, max_depth, X_train, X_test, y_train, y_test, coefs, eta)

# %%
evaluate_alg(X_train, X_test, y_train, y_test, trees, coefs, eta)
# Out:
# Ошибка алгоритма из 100 деревьев глубиной 3     с шагом 0.01 на тренировочной выборке: 6184.390174205517
# Ошибка алгоритма из 100 деревьев глубиной 3     с шагом 0.01 на тестовой выборке: 5886.520199489362

# %%
get_error_plot(n_trees, train_errors, test_errors)

# %%
eta = 0.1
max_depth = 5

trees, train_errors, test_errors = gb_fit(n_trees, max_depth, X_train, X_test, y_train, y_test, coefs, eta)

# %%
mse_s = []
mse_s.append([train_errors[-1], test_errors[-1]])
mse_s
# Out:
# [[82.96243297394945, 3982.3526833321534]]

# %%
evaluate_alg(X_train, X_test, y_train, y_test, trees, coefs, eta)
# Out:
# Ошибка алгоритма из 100 деревьев глубиной 5     с шагом 0.1 на тренировочной выборке: 78.89870443619806
# Ошибка алгоритма из 100 деревьев глубиной 5     с шагом 0.1 на тестовой выборке: 3999.616326637584

# %%
get_error_plot(n_trees, train_errors, test_errors)

# %%
eta = 0.1
graph = []
n_trees_s = np.linspace(1, 200, dtype = np.int)
max_depht_s = np.linspace(1,50, dtype = np.int)

# %%
for n_trees in n_trees_s:
    for max_depht in max_depht_s:
        trees, train_errors, test_errors = gb_fit(n_trees, max_depth, X_train, X_test, y_train, y_test, coefs, eta)
        graph.append([n_trees,max_depht,train_errors[-1], test_errors[-1]])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-4d42bdc8b6fc> in <module>
#       1 for n_trees in n_trees_s:
#       2     for max_depht in max_depht_s:
# ----> 3         trees, train_errors, test_errors = gb_fit(n_trees, max_depth, X_train, X_test, y_train, y_test, coefs, eta)
#       4         graph.append([n_trees,max_depht,train_errors[-1], test_errors[-1]])
#
# <ipython-input-18-c0b320b50ea5> in gb_fit(n_trees, max_depth, X_train, X_test, y_train, y_test, coefs, eta)
#      21         else:
#      22             # Получим ответы на текущей композиции
# ---> 23             target = gb_predict(X_train, trees, coefs, eta)
#      24
#      25             # алгоритмы начиная со второго обучаем на сдвиг
#
# <ipython-input-15-f555c35c120a> in gb_predict(X, trees_list, coef_list, eta)
# ...

# %%
plot_xyz = graph.copy()
plot_xyz = np.array(plot_xyz)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(plot_xyz[:,0], plot_xyz[:,1], plot_xyz[:,2], label='')
ax.set_xlabel("Количество деревьев")
ax.set_ylabel("Глубина деревьев")
ax.set_zlabel("Ошибка MSE Train")
# Out:
# Text(0.5, 0, 'Ошибка MSE Train')

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(plot_xyz[:,0], plot_xyz[:,1], plot_xyz[:,3], label='Зависимость ошибки на тесте от глубины и количества деревьев')
ax.set_xlabel("Количество деревьев")
ax.set_ylabel("Глубина деревьев")
ax.set_zlabel("Ошибка MSE Test")
# Out:
# Text(0.5, 0, 'Ошибка MSE Test')

# %%
fig, ax = plt.subplots(nrows = 1, ncols =2)
ax[0].plot(plot_xyz[:,1], plot_xyz[:,2])
ax[0].set_xlabel("Глубина деревьев")
ax[0].set_ylabel("Значение MSE")
ax[1].plot(plot_xyz[:,0], plot_xyz[:,2])
ax[1].set_xlabel("Количество деревьев")
ax[1].set_ylabel("Значение MSE")
# Out:
# Text(0, 0.5, 'Значение MSE')

# %% [markdown]
# На графиках хорошо видно, что лушким вариантом является увеличение количества деревьев, а не их глубины. Увеличение количества деревьев, кроме того,будет работать быстрее, чем увеличение глубины дерева. Полученные результаты хорошо соотносятся с теорией градиентного бустинга.
